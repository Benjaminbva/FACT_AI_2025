# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gnnboundary import *

# %%
import torch

# %% [markdown]
# # ENZYMES

# %%
dataset = ENZYMESDataset(seed=12345)

# %%
model = GCNClassifier(node_features=len(dataset.NODE_CLS),
                      num_classes=len(dataset.GRAPH_CLS),
                      hidden_channels=32,
                      num_layers=3)
model.load_state_dict(torch.load('ckpts/enzymes.pt'))
# Out:
# <All keys matched successfully>

# %%
dataset_list_gt = dataset.split_by_class()
dataset_list_pred = dataset.split_by_pred(model)
# Out:
# /home/gilian/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /home/gilian/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)

# %%
evaluation = dataset.model_evaluate(model)
evaluation
# Out:
# /home/gilian/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# {'acc': 0.7350000143051147,
#  'cm': array([[65,  3,  5,  9,  7, 11],
#         [ 5, 65,  8,  8,  7,  7],
#         [ 4,  4, 83,  1,  1,  7],
#         [ 9,  6,  1, 71,  5,  8],
#         [ 3,  5,  6,  0, 80,  6],
#         [ 4,  8,  3,  2,  6, 77]]),
#  'f1': {'EC1': 0.6842105388641357,
#   'EC2': 0.6806282997131348,
#   'EC3': 0.8058252334594727,
#   'EC4': 0.7434554696083069,
#   'EC5': 0.7766990065574646,
#   'EC6': 0.7129629850387573}}

# %%
draw_matrix(evaluation['cm'], dataset.GRAPH_CLS.values(), fmt='d')

# %%
mean_embeds = [d.model_transform(model, key="embeds").mean(dim=0) for d in dataset_list_gt]
# Out:
# /home/gilian/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
adj_ratio_mat, boundary_info = pairwise_boundary_analysis(model, dataset_list_pred)
draw_matrix(adj_ratio_mat, names=dataset.GRAPH_CLS.values(), fmt='.2f')

# %%
trainer = {}
sampler = {}

# %% [markdown]
# # 0 & 3

# %%
from lib.trainer import TrainerGPU

cls_1, cls_2 = 0, 3
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=1, beta=1
        ), weight=5),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=0),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=0),
        dict(key="logits", criterion=MeanPenalty(), weight=0),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=0),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=10, order=2, beta=1),
)

# %%
torch.manual_seed(0)

cls_1, cls_2 = 0, 3
trainer[cls_1, cls_2].train(
    iterations=1000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/gilian/Documents/uva/Master jaar 1/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb Cell 15 line 4
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> torch.manual_seed(0)
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> cls_1, cls_2 = 0, 3
# ----> <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> trainer[cls_1, cls_2].train(
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>     iterations=1000,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a>     target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a>     target_size=40,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a>     w_budget_init=1,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a>     w_budget_inc=1.1,
#      <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a>     w_budget_dec=0.95,
#      <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a>     k_samples=16
#      <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> )
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/gnn_xai_common/trainer.py:66, in Trainer.train(self, iterations, show_progress, target_probs, target_size, w_budget_init, w_budget_inc, w_budget_dec, k_samples)
#      64 disc_data = self.sampler(k=1, mode='discrete', expected=True)
#      65 # TODO: potential bug
# ---> 66 cont_out = self.discriminator(cont_data, edge_weight=cont_data.edge_weight)
#      67 disc_out = self.discriminator(disc_data, edge_weight=disc_data.edge_weight)
#      68 if target_probs and all([
#      69     min_p <= disc_out["probs"][0, classes].item() <= max_p
#      70     for classes, (min_p, max_p) in target_probs.items()
#      71 ]):
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/gnn_xai_common/models/gcn_classifier.py:30, in GCNClassifier.forward(self, batch, embeds, embeds_last, edge_weight, temperature)
#      24 node_weight = (None if edge_weight is None
#      25                else smooth_maximum_weight_propagation(batch.edge_index, edge_weight,
#      26                                                       size=len(batch.x),
#      27                                                       temperature=temperature))
#      29 # 1. Obtain node embeddings
# ---> 30 h = self.conv(batch.x, batch.edge_index, edge_weight=edge_weight)
#      32 # 2. Readout layer
#      33 embeds = torch.cat([
#      34     global_sum_pool_weighted(h, batch=batch.batch, node_weight=node_weight),
#      35     global_mean_pool_weighted(h, batch=batch.batch, node_weight=node_weight),
#      36 ], dim=1)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/models/basic_gnn.py:252, in BasicGNN.forward(self, x, edge_index, edge_weight, edge_attr, batch, batch_size, num_sampled_nodes_per_hop, num_sampled_edges_per_hop)
#     249     x = conv(x, edge_index, edge_weight=edge_weight,
#     250              edge_attr=edge_attr)
#     251 elif self.supports_edge_weight:
# --> 252     x = conv(x, edge_index, edge_weight=edge_weight)
#     253 elif self.supports_edge_attr:
#     254     x = conv(x, edge_index, edge_attr=edge_attr)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/conv/gcn_conv.py:260, in GCNConv.forward(self, x, edge_index, edge_weight)
#     257         else:
#     258             edge_index = cache
# --> 260 x = self.lin(x)
#     262 # propagate_type: (x: Tensor, edge_weight: OptTensor)
#     263 out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/dense/linear.py:147, in Linear.forward(self, x)
#     141 def forward(self, x: Tensor) -> Tensor:
#     142     r"""Forward pass.
#     143
#     144     Args:
#     145         x (torch.Tensor): The input features.
#     146     """
# --> 147     return F.linear(x, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_mm)

# %%
trainer[0, 3].evaluate(threshold=0.5, show=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/gilian/Documents/uva/Master jaar 1/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> trainer[0, 3].evaluate(threshold=0.5, show=True)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Documents/uva/Master jaar 1/fact/FACT_AI_2025/GNNBoundary/lib/trainer.py:137, in Trainer.evaluate(self, show, connected, *args, **kwargs)
#     135     G = sorted([G.subgraph(c) for c in nx.connected_components(G)], key=lambda g: g.number_of_nodes())[-1]
#     136 if show:
# --> 137     self.show(G)
#     138     plt.show()
#     139 return G
#
# File ~/Documents/uva/Master jaar 1/fact/FACT_AI_2025/GNNBoundary/lib/trainer.py:144, in Trainer.show(self, G, ax)
#     142 n = G.number_of_nodes()
#     143 m = G.number_of_edges()
# --> 144 pred = self.predict(G)
#     145 logits = pred["logits"].mean(dim=0).tolist()
#     146 probs = pred["probs"].mean(dim=0).tolist()
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Documents/uva/Master jaar 1/fact/FACT_AI_2025/GNNBoundary/lib/trainer.py:111, in Trainer.predict(self, G)
#     108 @torch.no_grad()
#     109 def predict(self, G):
#     110     batch = pyg.data.Batch.from_data_list([self.dataset.convert(G, generate_label=True)])
# --> 111     return self.discriminator(batch)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/gnn_xai_common/models/gcn_classifier.py:30, in GCNClassifier.forward(self, batch, embeds, embeds_last, edge_weight, temperature)
#      24 node_weight = (None if edge_weight is None
#      25                else smooth_maximum_weight_propagation(batch.edge_index, edge_weight,
#      26                                                       size=len(batch.x),
#      27                                                       temperature=temperature))
#      29 # 1. Obtain node embeddings
# ---> 30 h = self.conv(batch.x, batch.edge_index, edge_weight=edge_weight)
#      32 # 2. Readout layer
#      33 embeds = torch.cat([
#      34     global_sum_pool_weighted(h, batch=batch.batch, node_weight=node_weight),
#      35     global_mean_pool_weighted(h, batch=batch.batch, node_weight=node_weight),
#      36 ], dim=1)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/models/basic_gnn.py:252, in BasicGNN.forward(self, x, edge_index, edge_weight, edge_attr, batch, batch_size, num_sampled_nodes_per_hop, num_sampled_edges_per_hop)
#     249     x = conv(x, edge_index, edge_weight=edge_weight,
#     250              edge_attr=edge_attr)
#     251 elif self.supports_edge_weight:
# --> 252     x = conv(x, edge_index, edge_weight=edge_weight)
#     253 elif self.supports_edge_attr:
#     254     x = conv(x, edge_index, edge_attr=edge_attr)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/conv/gcn_conv.py:260, in GCNConv.forward(self, x, edge_index, edge_weight)
#     257         else:
#     258             edge_index = cache
# --> 260 x = self.lin(x)
#     262 # propagate_type: (x: Tensor, edge_weight: OptTensor)
#     263 out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/dense/linear.py:147, in Linear.forward(self, x)
#     141 def forward(self, x: Tensor) -> Tensor:
#     142     r"""Forward pass.
#     143
#     144     Args:
#     145         x (torch.Tensor): The input features.
#     146     """
# --> 147     return F.linear(x, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_mm)

# %% [markdown]
# # 0 & 4

# %%
cls_1, cls_2 = 0, 4
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=2, beta=1
        ), weight=15),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=1),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=1),
        dict(key="logits", criterion=MeanPenalty(), weight=5),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=0),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=10, order=2, beta=1),
)

# %%
cls_1, cls_2 = 0, 4
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#  13%|#2        | 290/2290 [00:00<?, ?it/s]
# False

# %%
trainer[0, 4].evaluate(threshold=0.5, show=True)
# Out:
# n=24 m=35
# logits=[-28.113203048706055, -24.9467830657959, -23.518278121948242, -31.32551383972168, -25.663606643676758, -25.71726417541504]
# probs=[0.006835011765360832, 0.16214290261268616, 0.6765342354774475, 0.0002752012514974922, 0.07917451858520508, 0.07503817975521088]

# %% [markdown]
# # 0 & 5

# %%
cls_1, cls_2 = 0, 5
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=2, beta=1
        ), weight=15),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=1),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=1),
        dict(key="logits", criterion=MeanPenalty(), weight=5),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=0),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=10, order=2, beta=1),
)

# %%
cls_1, cls_2 = 0, 5
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gilian/Documents/uva/Master jaar 1/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb Cell 23 line 2
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> cls_1, cls_2 = 0, 5
# ----> <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> trainer[cls_1, cls_2].train(
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a>     iterations=2000,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a>     target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a>     target_size=40,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a>     w_budget_init=1,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a>     w_budget_inc=1.1,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a>     w_budget_dec=0.95,
#       <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a>     k_samples=16
#      <a href='vscode-notebook-cell:/home/gilian/Documents/uva/Master%20jaar%201/fact/FACT_AI_2025/GNNBoundary/gnnboundary_enzymes.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> )
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/gnn_xai_common/trainer.py:67, in Trainer.train(self, iterations, show_progress, target_probs, target_size, w_budget_init, w_budget_inc, w_budget_dec, k_samples)
#      65 # TODO: potential bug
#      66 cont_out = self.discriminator(cont_data, edge_weight=cont_data.edge_weight)
# ---> 67 disc_out = self.discriminator(disc_data, edge_weight=disc_data.edge_weight)
#      68 if target_probs and all([
#      69     min_p <= disc_out["probs"][0, classes].item() <= max_p
#      70     for classes, (min_p, max_p) in target_probs.items()
#      71 ]):
#      72     if target_size and self.sampler.expected_m <= target_size:
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/gnn_xai_common/models/gcn_classifier.py:30, in GCNClassifier.forward(self, batch, embeds, embeds_last, edge_weight, temperature)
#      24 node_weight = (None if edge_weight is None
#      25                else smooth_maximum_weight_propagation(batch.edge_index, edge_weight,
#      26                                                       size=len(batch.x),
#      27                                                       temperature=temperature))
#      29 # 1. Obtain node embeddings
# ---> 30 h = self.conv(batch.x, batch.edge_index, edge_weight=edge_weight)
#      32 # 2. Readout layer
#      33 embeds = torch.cat([
#      34     global_sum_pool_weighted(h, batch=batch.batch, node_weight=node_weight),
#      35     global_mean_pool_weighted(h, batch=batch.batch, node_weight=node_weight),
#      36 ], dim=1)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/models/basic_gnn.py:252, in BasicGNN.forward(self, x, edge_index, edge_weight, edge_attr, batch, batch_size, num_sampled_nodes_per_hop, num_sampled_edges_per_hop)
#     249     x = conv(x, edge_index, edge_weight=edge_weight,
#     250              edge_attr=edge_attr)
#     251 elif self.supports_edge_weight:
# --> 252     x = conv(x, edge_index, edge_weight=edge_weight)
#     253 elif self.supports_edge_attr:
#     254     x = conv(x, edge_index, edge_attr=edge_attr)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/conv/gcn_conv.py:241, in GCNConv.forward(self, x, edge_index, edge_weight)
#     239 cache = self._cached_edge_index
#     240 if cache is None:
# --> 241     edge_index, edge_weight = gcn_norm(  # yapf: disable
#     242         edge_index, edge_weight, x.size(self.node_dim),
#     243         self.improved, self.add_self_loops, self.flow, x.dtype)
#     244     if self.cached:
#     245         self._cached_edge_index = (edge_index, edge_weight)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/nn/conv/gcn_conv.py:99, in gcn_norm(edge_index, edge_weight, num_nodes, improved, add_self_loops, flow, dtype)
#      96 num_nodes = maybe_num_nodes(edge_index, num_nodes)
#      98 if add_self_loops:
# ---> 99     edge_index, edge_weight = add_remaining_self_loops(
#     100         edge_index, edge_weight, fill_value, num_nodes)
#     102 if edge_weight is None:
#     103     edge_weight = torch.ones((edge_index.size(1), ), dtype=dtype,
#     104                              device=edge_index.device)
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/utils/loop.py:637, in add_remaining_self_loops(edge_index, edge_attr, fill_value, num_nodes)
#     629     loop_index = EdgeIndex(
#     630         torch.arange(0, N, device=device).view(1, -1).repeat(2, 1),
#     631         sparse_size=(N, N),
#     632         is_undirected=True,
#     633     )
#     635 if edge_attr is not None:
# --> 637     loop_attr = compute_loop_attr(  #
#     638         edge_index, edge_attr, N, False, fill_value)
#     640     inv_mask = ~mask
#     641     loop_attr[edge_index[0][inv_mask]] = edge_attr[inv_mask]
#
# File ~/miniconda3/envs/gnnboundary/lib/python3.11/site-packages/torch_geometric/utils/loop.py:755, in compute_loop_attr(edge_index, edge_attr, num_nodes, is_sparse, fill_value)
#     753 elif isinstance(fill_value, (int, float)):
#     754     size = (num_nodes, ) + edge_attr.size()[1:]
# --> 755     return edge_attr.new_full(size, fill_value)
#     757 elif isinstance(fill_value, Tensor):
#     758     size = (num_nodes, ) + edge_attr.size()[1:]
#
# KeyboardInterrupt:

# %%
trainer[0, 5].evaluate(threshold=0.5, show=True)
# Out:
# n=21 m=39
# logits=[-24.56463050842285, -22.195329666137695, -22.34037208557129, -27.280153274536133, -24.235933303833008, -22.223024368286133]
# probs=[0.030497297644615173, 0.3260135352611542, 0.2819969952106476, 0.0020180167630314827, 0.04236553609371185, 0.3171085715293884]

# %% [markdown]
# # 1 & 2

# %%
cls_1, cls_2 = 1, 2
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=1, beta=1
        ), weight=5),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=0),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=0),
        dict(key="logits", criterion=MeanPenalty(), weight=1),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=0),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=10, order=2, beta=1),
)

# %%
cls_1, cls_2 = 1, 2
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# True

# %%
trainer[1, 2].evaluate(threshold=0.5, show=True)
# Out:
# n=18 m=30
# logits=[-21.88401222229004, -19.303346633911133, -18.927473068237305, -22.532743453979492, -25.3548641204834, -22.17720603942871]
# probs=[0.028787828981876373, 0.38016989827156067, 0.5536273717880249, 0.015047644264996052, 0.0008950289920903742, 0.02147219516336918]

# %% [markdown]
# # 1 & 5

# %%
cls_1, cls_2 = 1, 5
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=1, beta=2
        ), weight=5),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=0),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=0),
        dict(key="logits", criterion=MeanPenalty(), weight=1),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=0),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=15, order=2, beta=1),
)

# %%
cls_1, cls_2 = 1, 5
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# True

# %%
trainer[1, 5].evaluate(threshold=0.5, show=True)
# Out:
# n=21 m=37
# logits=[-33.36986541748047, -27.398815155029297, -29.715009689331055, -33.64381408691406, -31.411882400512695, -27.43778419494629]
# probs=[0.0012249458814039826, 0.48007720708847046, 0.047358788549900055, 0.0009314134949818254, 0.008678769692778587, 0.46172890067100525]

# %% [markdown]
# # 2 & 4

# %%
cls_1, cls_2 = 2, 4
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=1, beta=1
        ), weight=10),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=1),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=1),
        dict(key="logits", criterion=MeanPenalty(), weight=1),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=1),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=15, order=2, beta=1),
)

# %%
cls_1, cls_2 = 2, 4
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# True

# %%
trainer[2, 4].evaluate(threshold=0.5, show=True)
# Out:
# n=22 m=37
# logits=[-70.59919738769531, -71.1167984008789, -48.922794342041016, -71.87195587158203, -49.52693176269531, -66.60327911376953]
# probs=[2.4928434316784376e-10, 1.4856063601520475e-10, 0.6466022729873657, 6.981407812967078e-11, 0.3533976674079895, 1.3555023770095431e-08]

# %% [markdown]
# # 3 & 4

# %%
cls_1, cls_2 = 3, 4
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=20,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=5, beta=1
        ), weight=20),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=1),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=1),
        dict(key="logits", criterion=MeanPenalty(), weight=5),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=1),
    ]),
    optimizer=(o := torch.optim.Adam(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=10, order=2, beta=1),
)

# %%
cls_1, cls_2 = 3, 4
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# True

# %%
trainer[3, 4].evaluate(threshold=0.5, show=True)
# Out:
# n=18 m=42
# logits=[-50.347808837890625, -46.284542083740234, -44.1386833190918, -36.10085678100586, -37.6645622253418, -42.34949493408203]
# probs=[5.361038120099693e-07, 3.118194581475109e-05, 0.0002665863139554858, 0.825318455696106, 0.17278774082660675, 0.0015954106347635388]

# %% [markdown]
# # 4 & 5

# %%
cls_1, cls_2 = 4, 5
trainer[cls_1, cls_2] = Trainer(
    sampler=(s := GraphSampler(
        max_nodes=25,
        temperature=0.2,
        num_node_cls=len(dataset.NODE_CLS),
        learn_node_feat=True
    )),
    discriminator=model,
    criterion=WeightedCriterion([
        dict(key="logits", criterion=DynamicBalancingBoundaryCriterion(
            classes=[cls_1, cls_2], alpha=1, beta=1
        ), weight=5),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_1]), weight=0),
        dict(key="embeds", criterion=EmbeddingCriterion(target_embedding=mean_embeds[cls_2]), weight=0),
        dict(key="logits", criterion=MeanPenalty(), weight=1),
        dict(key="omega", criterion=NormPenalty(order=1), weight=1),
        dict(key="omega", criterion=NormPenalty(order=2), weight=1),
        # dict(key="xi", criterion=NormPenalty(order=1), weight=0),
        # dict(key="xi", criterion=NormPenalty(order=2), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=1), weight=0),
        # dict(key="eta", criterion=NormPenalty(order=2), weight=0),
        dict(key="theta_pairs", criterion=KLDivergencePenalty(binary=True), weight=1),
    ]),
    optimizer=(o := torch.optim.SGD(s.parameters(), lr=1)),
    scheduler=torch.optim.lr_scheduler.ExponentialLR(o, gamma=1),
    dataset=dataset,
    budget_penalty=BudgetPenalty(budget=15, order=2, beta=1),
)

# %%
cls_1, cls_2 = 4, 5
trainer[cls_1, cls_2].train(
    iterations=2000,
    target_probs={cls_1: (0.4, 0.6), cls_2: (0.4, 0.6)},
    target_size=40,
    w_budget_init=1,
    w_budget_inc=1.1,
    w_budget_dec=0.95,
    k_samples=16
)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# True

# %%
trainer[4, 5].evaluate(threshold=0.5, show=True)
# Out:
# n=21 m=35
# logits=[-45.18898391723633, -54.12496566772461, -54.92832946777344, -54.68266677856445, -31.738271713256836, -31.534765243530273]
# probs=[6.470895073107386e-07, 8.51366893650507e-11, 3.812591908847196e-11, 4.874277717559217e-11, 0.4492979347705841, 0.550701379776001]
